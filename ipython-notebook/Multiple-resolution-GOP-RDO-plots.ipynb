# %%
import matplotlib.pyplot as plt
#plt.style.use('classic')

# %% [markdown]
# **VTL (288p) Fast**

# %%
#H264
psnr_avg_288_x264 =  [29.754115726323402, 31.46512183453182, 33.83759742127361, 35.65705732026373, 37.4859672332022, 39.34068915625704, 41.24222322573184]
ssim_avg_288_x264 =  [0.9570364587146127, 0.9715783858519825, 0.9835752036866243, 0.9891197634400593, 0.9928097539918612, 0.9951808763382957, 0.9967616314261077]
vma_avg_288_x264 =  [68.21127616918902, 77.60494440465746, 86.71938791898792, 91.33244570476062, 94.18361200983027, 95.99323420339711, 97.15250520640608]
bpp_288_x264 =  [0.021907700912635122, 0.03201784844054581, 0.055662906477051216, 0.08770301701222753, 0.14278314947722842, 0.23970414119262803, 0.4046635488658515]

#H265
psnr_avg_288_x265 =  [30.820625288608984, 32.46037060511254, 34.69025753929543, 36.3603467254899, 38.043700293955, 39.72734003209159, 41.43248374313626]
ssim_avg_288_x265 =  [0.9644128571525591, 0.9757374670419824, 0.985324416869537, 0.9898989473005727, 0.9929933085366679, 0.9950858612494088, 0.9965214332373212]
vma_avg_288_x265 =  [72.76422979719489, 80.83386359649131, 88.3373953286577, 92.0765527244922, 94.50123621625507, 96.09956563246749, 97.14906233618954]
bpp_288_x265 =  [0.02460044524189261, 0.03603579656211235, 0.06224453969519759, 0.09600007752968279, 0.15126727804359383, 0.2388814681906787, 0.3724096779195463]

#VP9, realtime
psnr_avg_288_vpx =  [34.90426203826011, 37.11502108936228, 39.042065104077125, 40.28405492668368, 41.658158168626045, 42.58341682604147]
ssim_avg_288_vpx =  [0.984577337840378, 0.9902908574426549, 0.9934031323497673, 0.9947939162793539, 0.9959894678224819, 0.9966341347131006]
vma_avg_288_vpx =  [89.12816132384262, 93.41145381966469, 95.65542222286982, 96.61147835427653, 97.36438850880339, 97.74218523156463]
bpp_288_vpx =  [0.07124814482544746, 0.12979487861066807, 0.21761997718412193, 0.3020827518607124, 0.4256644016923622, 0.527592426457558]

#-------------------------------PLOTS--------------------------------------

fig, plots = plt.subplots(3, 1)
#psnr
plots[0].plot(bpp_288_x264,  psnr_avg_288_x264,  'r', label='H264')
plots[0].plot(bpp_288_x265,  psnr_avg_288_x265,  'b', label='H265')
plots[0].plot(bpp_288_vpx,   psnr_avg_288_vpx,  'g', label='VP9')
plots[0].grid()

#ms-ssim
plots[1].plot(bpp_288_x264, ssim_avg_288_x264, 'r', label='H264')
plots[1].plot(bpp_288_x265, ssim_avg_288_x265, 'b', label='H265')
plots[1].plot(bpp_288_vpx,  ssim_avg_288_vpx,  'g', label='VP9')
plots[1].grid()

#vmaf
plots[2].plot(bpp_288_x264, vma_avg_288_x264, 'r', label='H264')
plots[2].plot(bpp_288_x265, vma_avg_288_x265, 'b', label='H265')
plots[2].plot(bpp_288_vpx,  vma_avg_288_vpx,  'g', label='VP9')
plots[2].grid()

plots[0].set(xlabel='bpp', ylabel='PSNR')
plots[1].set(xlabel='bpp', ylabel='MS-SSIM')
plots[2].set(xlabel='bpp', ylabel='VMAF')

fig.suptitle('Rate-Distortion')
plt.legend()
plt.show()

# %% [markdown]
# **480p, Fast**

# %%
#@title
#H264

#H265

#VP9, realtime


#-------------------------------PLOTS--------------------------------------

fig, plots = plt.subplots(3, 1)
#psnr
plots[0].plot(bpp_288_x264,  psnr_avg_288_x264,  'r', label='H264')#, marker='s')
plots[0].plot(bpp_288_x265,  psnr_avg_288_x265,  'b', label='H265')#, marker='s')
plots[0].plot(bpp_288_vpx,   psnr_avg_288_vpx,  'g', label='VP9')#, marker='s')
plots[0].grid()

#ms-ssim
plots[1].plot(bpp_288_x264, ssim_avg_288_x264, 'r', label='H264')#, marker='s')
plots[1].plot(bpp_288_x265, ssim_avg_288_x265, 'b', label='H265')#, marker='s')
plots[1].plot(bpp_288_vpx,  ssim_avg_288_vpx,  'g', label='VP9')#, marker='s')
plots[1].grid()

#vmaf
plots[2].plot(bpp_288_x264, vma_avg_288_x264, 'r', label='H264')#, marker='s')
plots[2].plot(bpp_288_x265, vma_avg_288_x265, 'b', label='H265')#, marker='s')
plots[2].plot(bpp_288_vpx,  vma_avg_288_vpx,  'g', label='VP9')#, marker='s')
plots[2].grid()

plots[0].set(xlabel='bpp', ylabel='PSNR')
plots[1].set(xlabel='bpp', ylabel='MS-SSIM')
plots[2].set(xlabel='bpp', ylabel='VMAF')

fig.suptitle('Rate-Distortion')
plt.legend()
plt.show()

# %% [markdown]
# **720p, Fast**

# %%
#H264
psnr_avg_720_x264 =  [31.050446661051883, 32.644511676466664, 34.76400351151083, 36.27804104638798, 37.669991218418616, 39.06027153040661, 40.73255209497907]
ssim_avg_720_x264 =  [0.9513512587540454, 0.9674958139771205, 0.9806537760337442, 0.9863979137436225, 0.9900379332711953, 0.9929527606158212, 0.9955454515345279]
vma_avg_720_x264  =  [68.6386799128547, 78.09835470310081, 87.44161899956028, 92.09575654971665, 94.8704561247713, 96.52134861846567, 97.63474216730256]
bpp_720_x264      =  [0.014962893518518518, 0.023809542824074072, 0.04617605902777778, 0.07899205439814815, 0.14299491319444443, 0.28363787037037036, 0.5588903935185185]

#H265
psnr_avg_720_x265 =  [32.45608752865375, 33.97447289322832, 35.86618381415015, 37.14821140199671, 38.31495989178558, 39.48388400630862, 40.87930992542785]
ssim_avg_720_x265 =  [0.963366194411272, 0.9745840921274903, 0.9837704408134723, 0.9879107677981734, 0.9906655960580684, 0.9928651274534446, 0.9949262714290683]
vma_avg_720_x265  =  [75.73282693599383, 83.21741377438602, 90.29440346330689, 93.4798307942287, 95.43408421681647, 96.7073360514199, 97.65349436365767]
bpp_720_x265      =  [0.01532626736111111, 0.025433240740740742, 0.05066778935185185, 0.08627644097222222, 0.14915967592592594, 0.26650408564814815, 0.4789995081018519]

#VP9, realtime
psnr_avg_720_vpx =  [35.24834833195176, 37.08878407876476, 38.544819995202566, 39.5736549391823, 40.85652403600979, 41.77102845354729]
ssim_avg_720_vpx =  [0.9797275520788231, 0.9867673761071044, 0.9903332504261814, 0.9921809594281651, 0.9940978102546385, 0.9952116005249699]
vma_avg_720_vpx  =  [89.48605998750686, 94.26919410964646, 96.30502083938697, 97.20656350691017, 97.89671381881406, 98.2147907685019]
bpp_720_vpx      =  [0.06027583912037037, 0.12015530092592593, 0.22878751157407407, 0.34942096643518517, 0.5434533333333333, 0.699930457175926]

#-------------------------------PLOTS--------------------------------------

fig, plots = plt.subplots(3, 1)
#psnr
plots[0].plot(bpp_720_x264,  psnr_avg_720_x264,  'r', label='H264')
plots[0].plot(bpp_720_x265,  psnr_avg_720_x265,  'b', label='H265')
plots[0].plot(bpp_720_vpx,   psnr_avg_720_vpx,  'g', label='VP9')
plots[0].grid()

#ms-ssim
plots[1].plot(bpp_720_x264, ssim_avg_720_x264, 'r', label='H264')
plots[1].plot(bpp_720_x265, ssim_avg_720_x265, 'b', label='H265')
plots[1].plot(bpp_720_vpx,  ssim_avg_720_vpx,  'g', label='VP9')
plots[1].grid()

#vmaf
plots[2].plot(bpp_720_x264, vma_avg_720_x264, 'r', label='H264')
plots[2].plot(bpp_720_x265, vma_avg_720_x265, 'b', label='H265')
plots[2].plot(bpp_720_vpx,  vma_avg_720_vpx,  'g', label='VP9')
plots[2].grid()

plots[0].set(xlabel='bpp', ylabel='PSNR')
plots[1].set(xlabel='bpp', ylabel='MS-SSIM')
plots[2].set(xlabel='bpp', ylabel='VMAF')

fig.suptitle('Rate-Distortion')
plt.legend()
plt.show()

# %% [markdown]
# **UVG (1080p) Fast**

# %%
#H264
psnr_avg_1080_x264 =  [34.64350910379509, 36.11825615944493, 38.02489145427959, 39.39244522366438, 40.678702458899075, 41.92142153605807, 43.20372524902765]
ssim_avg_1080_x264 =  [0.9508871682595029, 0.9657489385905339, 0.9788605005330838, 0.9848116187407742, 0.9888443314972847, 0.9921126065502059, 0.9947256943394656]
vma_avg_1080_x264  =  [62.945380403818895, 72.71726844528847, 83.19193643485995, 88.71539863732333, 92.35986487987402, 94.81000297225567, 96.65676361756634]
bpp_1080_x264      =  [0.01193338844797178, 0.018132510288065843, 0.03236088697824809, 0.05062247574955908, 0.08283496105232216, 0.15933705173427395, 0.3275490446796002]

#H265
psnr_avg_1080_x265 =  [35.61729748967624, 37.00870296350944, 38.769130461072905, 39.98740680846846, 41.12554974021394, 42.20030084245135, 43.271658562533624]
ssim_avg_1080_x265 =  [0.9590456860125333, 0.9703473953967051, 0.9806215004439093, 0.9855671611751421, 0.9890044177506029, 0.9916488937093767, 0.9938676553284908]
vma_avg_1080_x265  =  [67.70641292966845, 76.05707509562443, 84.79234973601181, 89.19024954638432, 92.1788692960204, 94.2389120749928, 95.79955500993061]
bpp_1080_x265      =  [0.008588712522045855, 0.013823001175778954, 0.02577957451499118, 0.04048628380364491, 0.06529354423868312, 0.11507508450911229, 0.21653742283950617]

#VP9, realtime
psnr_avg_1080_vpx =  [38.760281112003334, 40.33702948164405, 41.54283038379144, 42.310463148255394, 43.13050538361431, 43.69756337243253]
ssim_avg_1080_vpx =  [0.9797860956865997, 0.9860972608437709, 0.9894186190336111, 0.9911900039344831, 0.9928792768442165, 0.9939410371085182]
vma_avg_1080_vpx =  [85.41546067957142, 90.8789161745804, 93.56702186737202, 94.96819071391417, 96.1112642172492, 96.73050088958703]
bpp_1080_vpx =  [0.027015024250440917, 0.0481991879776602, 0.07927875881834215, 0.12022256025867137, 0.19264554306290418, 0.2630994157848324]
#-------------------------------PLOTS--------------------------------------

fig, plots = plt.subplots(3, 1)

#psnr
plots[0].plot(bpp_1080_x264,  psnr_avg_1080_x264,  'r', label='H264')
plots[0].plot(bpp_1080_x265,  psnr_avg_1080_x265,  'b', label='H265')
plots[0].plot(bpp_1080_vpx,   psnr_avg_1080_vpx,  'b', label='VP9')
plots[0].grid()

#ms-ssim
plots[1].plot(bpp_1080_x264, ssim_avg_1080_x264, 'r', label='H264')
plots[1].plot(bpp_1080_x265, ssim_avg_1080_x265, 'b', label='H265')
plots[1].plot(bpp_1080_vpx,  ssim_avg_1080_vpx,  'g', label='VP9')
plots[1].grid()

#vmaf
plots[2].plot(bpp_1080_x264, vma_avg_1080_x264, 'r', label='H264')
plots[2].plot(bpp_1080_x265, vma_avg_1080_x265, 'b', label='H265')
plots[2].plot(bpp_1080_vpx,  vma_avg_1080_vpx,  'g', label='VP9')
plots[2].grid()

plots[0].set(xlabel='bpp', ylabel='PSNR')
plots[1].set(xlabel='bpp', ylabel='MS-SSIM')
plots[2].set(xlabel='bpp', ylabel='VMAF')

fig.suptitle('Rate-Distortion')
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# **VTL (288p) Slow**

# %%
#@title
#H264
psnr_avg_288_x264 =  [29.883169740676102, 31.599752199762435, 33.99085957644483, 35.81486244120606, 37.657399266499205, 39.513903778178644, 41.40225118094072]
ssim_avg_288_x264 =  [0.9586545953066428, 0.9723767751610797, 0.9839264979936573, 0.9892906059278217, 0.9928802932129684, 0.9952295366953386, 0.9967982147186497]
vma_avg_288_x264 =  [70.3946338513643, 79.21280827428757, 87.84368930315966, 92.04917534884969, 94.71607695833552, 96.36855251555407, 97.37967644116546]
bpp_288_x264 =  [0.023408786328194223, 0.033761241804004964, 0.058122535663654086, 0.09031114323055113, 0.14524216950203792, 0.24132146575403154, 0.40610009082048554]

#H265
psnr_avg_288_x265 =  [31.483377122534325, 33.268673836671006, 35.6704824208711, 37.466666617592175, 39.24459088488615, 41.02586462339144, 42.8434666810946]
ssim_avg_288_x265 =  [0.9692115117561366, 0.9795036602915947, 0.9879428551587651, 0.9918080047962058, 0.9943320865487671, 0.9960242235728434, 0.9972191941791634]
vma_avg_288_x265 =  [77.930865231863, 85.28169329388386, 91.66635305089174, 94.37142918747298, 96.05070993226555, 97.11846433944883, 97.84325365049969]
bpp_288_x265 =  [0.027065833776360092, 0.04084980839092681, 0.07249656654261917, 0.11338123560163034, 0.17958626838561048, 0.28500418106503633, 0.449284982500443]

#-------------------------------PLOTS--------------------------------------

fig, plots = plt.subplots(3, 1)
#psnr
plots[0].plot(bpp_288_x264,  psnr_avg_288_x264,  'r', label='H264')#, marker='s')
plots[0].plot(bpp_288_x265,  psnr_avg_288_x265,  'b', label='H265')#, marker='s')
plots[0].grid()

#ms-ssim
plots[1].plot(bpp_288_x264, ssim_avg_288_x264, 'r', label='H264')#, marker='s')
plots[1].plot(bpp_288_x265, ssim_avg_288_x265, 'b', label='H265')#, marker='s')
plots[1].grid()

#vmaf
plots[2].plot(bpp_288_x264, vma_avg_288_x264, 'r', label='H264')#, marker='s')
plots[2].plot(bpp_288_x265, vma_avg_288_x265, 'b', label='H265')#, marker='s')
plots[2].grid()

plots[0].set(xlabel='bpp', ylabel='PSNR')
plots[1].set(xlabel='bpp', ylabel='MS-SSIM')
plots[2].set(xlabel='bpp', ylabel='VMAF')

fig.suptitle('Rate-Distortion')
plt.legend()
plt.show()

# %% [markdown]
# **UVG (1080p) Slow**

# %%
#@title
#H264
psnr_avg_1080_x264 =  [34.35599743541409, 35.915886351712615, 37.91814792848582, 39.339558103354754, 40.65374449340084, 41.86466570362088, 43.13334925859306]
ssim_avg_1080_x264 =  [0.9482986190613178, 0.9642406318855476, 0.9781281904450784, 0.9844245088477429, 0.9887100543190565, 0.9920069736147339, 0.9946793845518188]
vma_avg_1080_x264 =  [62.21055856485861, 72.6519868163513, 83.72710768283487, 89.4964801748167, 93.13097705350683, 95.44918859970855, 97.06485680570721]
bpp_1080_x264 =  [0.011585181510875956, 0.017672439006466784, 0.031723776455026456, 0.04972878821281599, 0.08166029541446208, 0.15798546443268666, 0.33440748824221045]

#H265
psnr_avg_1080_x265 =  [36.08537494091954, 37.58849537339694, 39.45277178258758, 40.722590817939576, 41.860615622228856, 42.94632333466278, 44.07527253096108]
ssim_avg_1080_x265 =  [0.9626140167431879, 0.9738777542835216, 0.98344788988358, 0.9877963298774061, 0.9905766130797781, 0.9930780316112132, 0.9951163563350617]
vma_avg_1080_x265 =  [72.59906483203586, 81.0391673751732, 88.84173422965299, 92.27768503374462, 94.51207389620924, 96.01452775061124, 97.1728630988431]
bpp_1080_x265 =  [0.009496667401528512, 0.015832168577307466, 0.029638139329805996, 0.046255610670194, 0.07320391681363904, 0.13621538800705468, 0.2690476925338036]

#-------------------------------PLOTS--------------------------------------

fig, plots = plt.subplots(3, 1)

#psnr
plots[0].plot(bpp_1080_x264,  psnr_avg_1080_x264,  'r', label='H264')#, marker='s')
plots[0].plot(bpp_1080_x265,  psnr_avg_1080_x265,  'b', label='H265')#, marker='s')
plots[0].grid()


#ms-ssim
plots[1].plot(bpp_1080_x264, ssim_avg_1080_x264, 'r', label='H264')#, marker='s')
plots[1].plot(bpp_1080_x265, ssim_avg_1080_x265, 'b', label='H265')#, marker='s')
plots[1].grid()


#vmaf
plots[2].plot(bpp_1080_x264, vma_avg_1080_x264, 'r', label='H264')#, marker='s')
plots[2].plot(bpp_1080_x265, vma_avg_1080_x265, 'b', label='H265')#, marker='s')
plots[2].grid()

plots[0].set(xlabel='bpp', ylabel='PSNR')
plots[1].set(xlabel='bpp', ylabel='MS-SSIM')
plots[2].set(xlabel='bpp', ylabel='VMAF')

fig.suptitle('Rate-Distortion')
plt.legend()
plt.show()

# %%
#h265
#gop 16
psnr_avg_288_libx265_16 =  [27.64876995759657, 29.47484998357443, 31.81990272784421, 33.58045409897363, 35.38165172950991, 37.28746520203359, 39.30590964773825]
ssim_avg_288_libx265_16 =  [0.9722418289557038, 0.9820923494344774, 0.9898327239483458, 0.9930101057710446, 0.9950880729097414, 0.9965023468457681, 0.9975160648418204]
vma_avg_288_libx265_16 =  [74.64191771140796, 83.53371392660803, 92.09548104597137, 95.74675213713256, 97.42720827221765, 98.4865961333318, 99.22088317266181]
bpp_288_libx265_16 =  [0.022941130050505052, 0.03204782196969697, 0.05019912668350168, 0.07087305345117845, 0.10076257365319866, 0.14527988215488216, 0.20882996632996634]

#gop30
psnr_avg_288_libx265_30 =  [27.60877267051888, 29.47769173525476, 31.82251014457196, 33.55915671699317, 35.32981728196433, 37.18416220960172, 39.15382377182688]
ssim_avg_288_libx265_30 =  [0.9715229912974386, 0.9822723984694518, 0.9898863102640667, 0.9930938696679555, 0.9951062325073996, 0.9964921374465616, 0.997478633163162]
vma_avg_288_libx265_30 =  [74.48847720093025, 83.96443141769926, 92.426700118305, 95.89719801409218, 97.48989182295234, 98.5300465114832, 99.1837890202564]
bpp_288_libx265_30 =  [0.01820970117845118, 0.02610637626262626, 0.04221354166666667, 0.06042140151515152, 0.08803977272727273, 0.12881655092592592, 0.189291351010101]

#gop 150
psnr_avg_288_libx265_150 =  [27.35535166298516, 29.29452392560895, 31.713924253709, 33.48975809956274, 35.27088119781232, 37.13278843719247, 39.10031760333185]
ssim_avg_288_libx265_150 =  [0.9692001251940571, 0.9813509947212408, 0.9895076926224552, 0.992955777060729, 0.9950725718035456, 0.9964655265579739, 0.9974655235838378]
vma_avg_288_libx265_150 =  [73.7366465423891, 83.72359083660217, 92.30586457491724, 95.93326184758915, 97.5469938831797, 98.50405821420266, 99.20806335937293]
bpp_288_libx265_150 =  [0.015258049242424243, 0.02234111952861953, 0.03710174663299663, 0.05430318813131313, 0.08087042297979798, 0.12078861531986532, 0.1804990004208754]
#-------------------------------PLOTS--------------------------------------

fig, plots = plt.subplots(3, 1)

#psnr
plots[0].plot(bpp_288_libx265_16,  psnr_avg_288_libx265_16,  'r', label='GOP-16')
plots[0].plot(bpp_288_libx265_30,  psnr_avg_288_libx265_30,  'b', label='GOP-30')
plots[0].plot(bpp_288_libx265_150,   psnr_avg_288_libx265_150,  'g', label='GOP-150')
plots[0].grid()

#ms-ssim
plots[1].plot(bpp_288_libx265_16, ssim_avg_288_libx265_16, 'r', label='GOP-16')
plots[1].plot(bpp_288_libx265_30, ssim_avg_288_libx265_30, 'b', label='GOP-30')
plots[1].plot(bpp_288_libx265_150,  ssim_avg_288_libx265_150,  'g', label='GOP-150')
plots[1].grid()

#vmaf
plots[2].plot(bpp_288_libx265_16, vma_avg_288_libx265_16, 'r', label='GOP-16')
plots[2].plot(bpp_288_libx265_30, vma_avg_288_libx265_30, 'b', label='GOP-30')
plots[2].plot(bpp_288_libx265_150,  vma_avg_288_libx265_150,  'g', label='GOP-150')
plots[2].grid()

plots[0].set(xlabel='bpp', ylabel='PSNR')
plots[1].set(xlabel='bpp', ylabel='MS-SSIM')
plots[2].set(xlabel='bpp', ylabel='VMAF')

fig.suptitle('Rate-Distortion')
plt.legend()
plt.show()
